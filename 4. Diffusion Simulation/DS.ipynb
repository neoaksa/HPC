# %% [markdown]
# <a href="https://colab.research.google.com/github/neoaksa/HPC/blob/master/4.%20Diffusion%20Simulation/DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pydrive
# these classes allow you to request the Google drive API
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials
from googleapiclient.discovery import build
from google.colab import auth

# authenticate google drive
auth.authenticate_user()
drive_service = build('drive', 'v3')
# 1. Authenticate and create the PyDrive client.
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

def downloadFile(inputfilename,outputfilename):
    downloaded = drive.CreateFile({'id': inputfilename})
    # assume the file is called file.csv and it's located at the root of your drive
    downloaded.GetContentFile(outputfilename)
# file download, the param is file id from google drive
FileObj = downloadFile("1b9JHOrS40KQtqrUwkvx3LP3Cw_i6FsWv","DS.csv")

# %%
import pandas as pd
header = ["Z","Y","X","value","time"]
df = pd.read_csv('DS.csv',index_col=None, 
                 header=None, usecols=[0,1,2,3,4], names=header)
df.head(10)
df.count()
# Out:
# Z        786432
# Y        786432
# X        786432
# value    786432
# time     786432
# dtype: int64

# %%
# library
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# make a plot for z=8 which is the middle slice of space, 
# and plot when dt=100,500,1000,3000,5000 respectly
fig, axearr = plt. subplots(3,2,sharex=True,sharey=True,figsize=(15,20))

# dt = 100
axearr[0,0] = fig.add_subplot(3, 2, 1, projection='3d')

dfs=df[(df.Z==8) & (df.time==100)]
# Make the plot
axearr[0,0] = fig.gca(projection='3d')
# set range of axis
axearr[0,0].set_xlim(0,64)
axearr[0,0].set_ylim(0,64)
axearr[0,0].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[0,0].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[0,0].view_init(10, 45)


# dt = 500
axearr[0,1] = fig.add_subplot(3, 2, 2, projection='3d')

dfs=df[(df.Z==8) & (df.time==500)]
# Make the plot
axearr[0,1] = fig.gca(projection='3d')
# set range of axis
axearr[0,1].set_xlim(0,64)
axearr[0,1].set_ylim(0,64)
axearr[0,1].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[0,1].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[0,1].view_init(10, 45)

# dt = 1000
axearr[1,0] = fig.add_subplot(3, 2, 3, projection='3d')

dfs=df[(df.Z==8) & (df.time==1000)]
# Make the plot
axearr[1,0] = fig.gca(projection='3d')
# set range of axis
axearr[1,0].set_xlim(0,64)
axearr[1,0].set_ylim(0,64)
axearr[1,0].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[1,0].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[1,0].view_init(10, 45)


# dt = 3000
axearr[1,1] = fig.add_subplot(3, 2, 4, projection='3d')

dfs=df[(df.Z==8) & (df.time==3000)]
# Make the plot
axearr[1,1] = fig.gca(projection='3d')
# set range of axis
axearr[1,1].set_xlim(0,64)
axearr[1,1].set_ylim(0,64)
axearr[1,1].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[1,1].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[1,1].view_init(10, 45)

# dt = 5000
axearr[2,0] = fig.add_subplot(3, 2, 5, projection='3d')

dfs=df[(df.Z==8) & (df.time==5000)]
# Make the plot
axearr[2,0] = fig.gca(projection='3d')
# set range of axis
axearr[2,0].set_xlim(0,64)
axearr[2,0].set_ylim(0,64)
axearr[2,0].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[2,0].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[2,0].view_init(10, 45)

# dt = 10000
axearr[2,1] = fig.add_subplot(3, 2, 6, projection='3d')

dfs=df[(df.Z==8) & (df.time==10000)]
# Make the plot
axearr[2,1] = fig.gca(projection='3d')
# set range of axis
axearr[2,1].set_xlim(0,64)
axearr[2,1].set_ylim(0,64)
axearr[2,1].invert_yaxis()
# to Add a color bar which maps values to colors.
surf=axearr[2,1].plot_trisurf(dfs['Y'], dfs['X'], dfs['value'], cmap=plt.cm.viridis, linewidth=0.2)
fig.colorbar( surf, shrink=0.5, aspect=5)
# Rotate it
axearr[2,1].view_init(10, 45)

plt.show()
